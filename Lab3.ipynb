# %% [raw]
# ###Lab3

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# limit column display size, so we don't have to scroll endlessly
pd.set_option('display.max_columns', 100)

# display plots inline
# %matplotlib inline

# %%
df = pd.read_csv("Results_2017-18.csv")

# %%
#df

# %% [markdown]
# Finding Grade Levels That have K instead of a number Value

# %%
df.loc[df['Entering Grade Level'] == 'K']
# Out:
#                Timestamp Entering Grade Level  District Birth Month  \
# 1      4/7/2017 10:40:45                    K       NaN      August
# 3      4/7/2017 10:43:31                    K       NaN   September
# 4     4/10/2017 10:18:34                    K      22.0       April
# 5      4/7/2017 11:03:21                    K       NaN         May
# 6      4/7/2017 11:15:28                    K       NaN    February
# ..                   ...                  ...       ...         ...
# 111    6/7/2017 23:25:27                    K       2.0    December
# 113   6/21/2017 22:52:59                    K      20.0        July
# 114   9/14/2017 16:39:55                    K      32.0    February
# 115  11/19/2017 17:07:05                    K       4.0       April
# 116   1/11/2019 15:03:41                    K       2.0     January
#
#     OLSAT Verbal Score OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# 1                   25                      99                        39
# ...

# %% [markdown]
# Changing all the K Values to 0

# %%
df.loc[df["Entering Grade Level"] == "K", "Entering Grade Level"] = 0

# %%
df.loc[df['Entering Grade Level'] == 0]
# Out:
#                Timestamp Entering Grade Level  District Birth Month  \
# 1      4/7/2017 10:40:45                    0       NaN      August
# 3      4/7/2017 10:43:31                    0       NaN   September
# 4     4/10/2017 10:18:34                    0      22.0       April
# 5      4/7/2017 11:03:21                    0       NaN         May
# 6      4/7/2017 11:15:28                    0       NaN    February
# ..                   ...                  ...       ...         ...
# 111    6/7/2017 23:25:27                    0       2.0    December
# 113   6/21/2017 22:52:59                    0      20.0        July
# 114   9/14/2017 16:39:55                    0      32.0    February
# 115  11/19/2017 17:07:05                    0       4.0       April
# 116   1/11/2019 15:03:41                    0       2.0     January
#
#     OLSAT Verbal Score OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# 1                   25                      99                        39
# ...

# %% [markdown]
# Getting the Column mean for District

# %%
districtMean = df["District"].mean()

# %%
districtMean
# Out:
# 12.504950495049505

# %% [markdown]
# Find Districts with NaN Values

# %%
df.loc[df['District'].isnull()]
# Out:
#             Timestamp Entering Grade Level  District Birth Month  \
# 1   4/7/2017 10:40:45                    0       NaN      August
# 2   4/7/2017 10:41:56                    1       NaN       March
# 3   4/7/2017 10:43:31                    0       NaN   September
# 5   4/7/2017 11:03:21                    0       NaN         May
# 6   4/7/2017 11:15:28                    0       NaN    February
# 7   4/7/2017 11:26:16                    0       NaN     October
# 8   4/7/2017 11:31:41                    1       NaN       March
# 9   4/7/2017 11:32:52                    2       NaN       April
# 10  4/7/2017 11:57:06                    0       NaN        June
# 11  4/7/2017 12:03:49                    0       NaN    December
# 12  4/7/2017 12:36:07                    1       NaN        July
# 13  4/7/2017 12:42:05                    1       NaN         May
# 14  4/7/2017 13:00:25                    1       NaN     January
# ...

# %% [markdown]
# Change the null to the mean of the district

# %%
df['District'].fillna(value=districtMean, inplace=True)

# %%
#df

# %% [markdown]
# Convert Months from strings to Numbers

# %%
#df

# %%
df.dtypes
# Out:
# Timestamp                      object
# Entering Grade Level           object
# District                      float64
# Birth Month                    object
# OLSAT Verbal Score             object
# OLSAT Verbal Percentile        object
# NNAT Non Verbal Raw Score      object
# NNAT Non Verbal Percentile      int64
# Overall Score                   int64
# School Preferences             object
# School Assigned                object
# Will you enroll there?         object
# dtype: object

# %%
df2= df.copy()

# %%
#df2

# %%
d = dict((v,k) for k,v in zip(range(1, 13), df2['Birth Month'].unique()))
# create column
df2['month_index'] = df2['Birth Month'].map(d)

# %%
#df2

# %%
d
# Out:
# {'September': 1,
#  'August': 2,
#  'March': 3,
#  'April': 4,
#  'May': 5,
#  'February': 6,
#  'October': 7,
#  'June': 8,
#  'December': 9,
#  'July': 10,
#  'January': 11,
#  'November': 12}

# %%
df2['Birth Month'].unique()
# Out:
# array(['September', 'August', 'March', 'April', 'May', 'February',
#        'October', 'June', 'December', 'July', 'January', 'November'],
#       dtype=object)

# %% [markdown]
# Dleteing the birth Month colum

# %%
del df2["Birth Month"]

# %%
df2
# Out:
#                Timestamp Entering Grade Level  District OLSAT Verbal Score  \
# 0       4/8/2017 6:44:01                    1   6.00000                 28
# 1      4/7/2017 10:40:45                    0  12.50495                 25
# 2      4/7/2017 10:41:56                    1  12.50495                 27
# 3      4/7/2017 10:43:31                    0  12.50495                 23
# 4     4/10/2017 10:18:34                    0  22.00000                 25
# ..                   ...                  ...       ...                ...
# 112   6/20/2017 16:06:54                    1   2.00000                 30
# 113   6/21/2017 22:52:59                    0  20.00000                 97
# 114   9/14/2017 16:39:55                    0  32.00000                 26
# 115  11/19/2017 17:07:05                    0   4.00000                 19
# 116   1/11/2019 15:03:41                    0   2.00000                 24
#
#     OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# ...

# %% [markdown]
# Changing the percentage and Verbal scores to Floats

# %%
df2.at[86,'OLSAT Verbal Percentile']=80
#PercentileMean = df["OLSAT Verbal Percentile"].mean()

# %%
col_list = df2['OLSAT Verbal Percentile'].values.tolist()

# %%
col_list
# Out:
# ['99',
#  '99',
#  '96',
#  '97',
#  '98',
#  '97',
#  '99',
#  '99',
#  '81',
#  '99',
#  '77',
#  '98',
#  '86',
#  '99',
#  '96',
#  '99',
#  '89',
#  '89',
#  '96',
#  '99',
#  '99',
#  '99',
#  '97',
#  '99',
#  '89',
#  '97',
#  '99',
#  '99',
#  '89',
#  '99',
#  '99',
#  '97',
#  '87',
#  '97',
#  '55',
#  '99',
#  '83',
#  '98',
#  '88',
#  '86',
#  '96',
#  '79',
#  '86',
#  '99',
#  '99',
#  '99',
#  '96',
#  '96',
#  '99',
#  '99',
#  '99',
#  '87',
#  '99',
#  '98',
#  '99',
#  '97',
#  '97',
#  '95',
#  '99',
#  '96',
#  '99',
#  '99',
#  '97',
#  '99',
#  '81',
#  '99',
#  '99',
#  '96',
#  '99',
#  '98',
#  '81',
#  '99',
#  '90',
#  '90',
#  '90',
#  '99',
#  '99',
#  '98',
#  '98',
#  '69',
#  '96',
#  '94',
#  '94',
#  '99',
#  '~70',
#  '98',
#  80,
#  '99',
#  '99',
#  '95',
#  '98',
#  '99',
#  '99',
#  '97',
#  '99',
#  '98',
#  '93',
#  '99',
#  '83',
#  '99',
#  '99',
#  '99',
#  '99',
#  '99',
#  '98',
#  '97',
#  '96',
#  '99',
#  '99',
#  '98',
#  '96',
# ...

# %% [markdown]
# Removing an odd value

# %%
index = col_list.index('~70')

# %%
index
# Out:
# 84

# %%
col_list[84] ='70'

# %%
col_list[84]
# Out:
# '70'

# %% [markdown]
# Change the values to a float

# %%
import numpy as np
col_list =list(np.float_(col_list))

# %% [markdown]
# Emptying the OLSAT verbal percentile

# %%
df2.drop('OLSAT Verbal Percentile', axis = 1, inplace = True)

# Put whatever series you want in its place
df2['OLSAT Verbal Percentile'] = col_list

# %%
df2['OLSAT Verbal Percentile']
# Out:
# 0      99.0
# 1      99.0
# 2      96.0
# 3      97.0
# 4      98.0
#        ...
# 112    99.0
# 113    97.0
# 114    99.0
# 115    84.0
# 116    97.0
# Name: OLSAT Verbal Percentile, Length: 117, dtype: float64

# %%
marks = []
for x in col_list:
    marks.append(x *30/100)

# %%
marks
# Out:
# [29.7,
#  29.7,
#  28.8,
#  29.1,
#  29.4,
#  29.1,
#  29.7,
#  29.7,
#  24.3,
#  29.7,
#  23.1,
#  29.4,
#  25.8,
#  29.7,
#  28.8,
#  29.7,
#  26.7,
#  26.7,
#  28.8,
#  29.7,
#  29.7,
#  29.7,
#  29.1,
#  29.7,
#  26.7,
#  29.1,
#  29.7,
#  29.7,
#  26.7,
#  29.7,
#  29.7,
#  29.1,
#  26.1,
#  29.1,
#  16.5,
#  29.7,
#  24.9,
#  29.4,
#  26.4,
#  25.8,
#  28.8,
#  23.7,
#  25.8,
#  29.7,
#  29.7,
#  29.7,
#  28.8,
#  28.8,
#  29.7,
#  29.7,
#  29.7,
#  26.1,
#  29.7,
#  29.4,
#  29.7,
#  29.1,
#  29.1,
#  28.5,
#  29.7,
#  28.8,
#  29.7,
#  29.7,
#  29.1,
#  29.7,
#  24.3,
#  29.7,
#  29.7,
#  28.8,
#  29.7,
#  29.4,
#  24.3,
#  29.7,
#  27.0,
#  27.0,
#  27.0,
#  29.7,
#  29.7,
#  29.4,
#  29.4,
#  20.7,
#  28.8,
#  28.2,
#  28.2,
#  29.7,
#  21.0,
#  29.4,
#  24.0,
#  29.7,
#  29.7,
#  28.5,
#  29.4,
#  29.7,
#  29.7,
#  29.1,
#  29.7,
#  29.4,
#  27.9,
#  29.7,
#  24.9,
#  29.7,
#  29.7,
#  29.7,
#  29.7,
#  29.7,
#  29.4,
#  29.1,
#  28.8,
#  29.7,
#  29.7,
#  29.4,
#  28.8,
# ...

# %%
df2.drop('OLSAT Verbal Score', axis = 1, inplace = True)

# Put whatever series you want in its place
df2['OLSAT Verbal Score'] = marks

# %%
df2
# Out:
#                Timestamp Entering Grade Level  District  \
# 0       4/8/2017 6:44:01                    1   6.00000
# 1      4/7/2017 10:40:45                    0  12.50495
# 2      4/7/2017 10:41:56                    1  12.50495
# 3      4/7/2017 10:43:31                    0  12.50495
# 4     4/10/2017 10:18:34                    0  22.00000
# ..                   ...                  ...       ...
# 112   6/20/2017 16:06:54                    1   2.00000
# 113   6/21/2017 22:52:59                    0  20.00000
# 114   9/14/2017 16:39:55                    0  32.00000
# 115  11/19/2017 17:07:05                    0   4.00000
# 116   1/11/2019 15:03:41                    0   2.00000
#
#     NNAT Non Verbal Raw Score  NNAT Non Verbal Percentile  Overall Score  \
# 0                          45                          99             99
# 1                          39                          99             99
# ...

# %% [markdown]
# Repeat the same thing for NNAT

# %%
col2_list = df2['NNAT Non Verbal Percentile'].values.tolist()

# %%
import numpy as np
col2_list =list(np.float_(col2_list))

# %%
df2.drop('NNAT Non Verbal Percentile', axis = 1, inplace = True)

# Put whatever series you want in its place
df2['NNAT Non Verbal Percentile'] = col2_list

# %%
marks1 = []
for x in col2_list:
    marks1.append(x *48/100)

# %%
df2.drop('NNAT Non Verbal Raw Score', axis = 1, inplace = True)

# Put whatever series you want in its place
df2['NNAT Non Verbal Raw Score'] = marks1

# %%
df2
# Out:
#                Timestamp Entering Grade Level  District  Overall Score  \
# 0       4/8/2017 6:44:01                    1   6.00000             99
# 1      4/7/2017 10:40:45                    0  12.50495             99
# 2      4/7/2017 10:41:56                    1  12.50495             98
# 3      4/7/2017 10:43:31                    0  12.50495             98
# 4     4/10/2017 10:18:34                    0  22.00000             99
# ..                   ...                  ...       ...            ...
# 112   6/20/2017 16:06:54                    1   2.00000             99
# 113   6/21/2017 22:52:59                    0  20.00000             98
# 114   9/14/2017 16:39:55                    0  32.00000             99
# 115  11/19/2017 17:07:05                    0   4.00000             91
# 116   1/11/2019 15:03:41                    0   2.00000             98
#
#                               School Preferences  \
# 0                    NEST+m, TAG, Anderson, Q300
# ...

# %%
df2['Will you enroll there?'].fillna(value=3, inplace=True)

# %%
df2['Will you enroll there?']
df2.loc[df2["Will you enroll there?"] == "Yes", "Will you enroll there?"] = 1
df2.loc[df2["Will you enroll there?"] == "YES", "Will you enroll there?"] = 1
df2.loc[df2["Will you enroll there?"] == "No", "Will you enroll there?"] = 2
df2.loc[df2["Will you enroll there?"] == "NO", "Will you enroll there?"] = 2
df2.loc[df2["Will you enroll there?"] == "Maybe", "Will you enroll there?"] = 3
df2.loc[df2["Will you enroll there?"] == "MAYBE", "Will you enroll there?"] = 3

# %%
df2['Will you enroll there?']
# Out:
# 0      1
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 112    1
# 113    1
# 114    3
# 115    1
# 116    1
# Name: Will you enroll there?, Length: 117, dtype: object

# %%
df2
# Out:
#                Timestamp Entering Grade Level  District  Overall Score  \
# 0       4/8/2017 6:44:01                    1   6.00000             99
# 1      4/7/2017 10:40:45                    0  12.50495             99
# 2      4/7/2017 10:41:56                    1  12.50495             98
# 3      4/7/2017 10:43:31                    0  12.50495             98
# 4     4/10/2017 10:18:34                    0  22.00000             99
# ..                   ...                  ...       ...            ...
# 112   6/20/2017 16:06:54                    1   2.00000             99
# 113   6/21/2017 22:52:59                    0  20.00000             98
# 114   9/14/2017 16:39:55                    0  32.00000             99
# 115  11/19/2017 17:07:05                    0   4.00000             91
# 116   1/11/2019 15:03:41                    0   2.00000             98
#
#                               School Preferences  \
# 0                    NEST+m, TAG, Anderson, Q300
# ...

# %% [markdown]
# Giving a unique number to each school

# %%
df2['School Preferences'].fillna(value='Anderson', inplace=True)

# %%
school =[]
school = df2['School Preferences'].values.tolist()

school
# Out:
# ['NEST+m, TAG, Anderson, Q300',
#  'Anderson, NEST+m',
#  'Anderson',
#  'Anderson',
#  'Brooklyn School of Inquiry',
#  'Anderson',
#  'Anderson NEST TAG Q300',
#  'Nest+M, Anderson',
#  'Anderson',
#  'Any citywide or district 3 school',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'PS121 ',
#  'Anderson, NEST+m',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson, NEST+M, Lower Lab',
#  'Anderson',
#  'PS Q203',
#  'Anderson',
#  'Anderson',
#  'Likely staying in zoned schools; D15 G&T options are limited.',
#  'TBD',
#  'Nest',
#  'Tag',
#  'PS229',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson, Tag Young, Nest+M',
#  'TBD',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'Nest',
#  'Any city-wide',
#  'Anderson',
#  'PS188',
#  'BSI',
#  'Anderson',
#  'Anderson',
#  'Anderson',
#  'NEST+M',
#  'Nest+m, BSI',
#  'Anderson',
#  'Anderson',
# ...

# %%
school_1 = [s for i in school if len(i.split(',')) > 1 for s in i.split(',')] + [i for i in school if len(i.split(',')) == 1]

# %%
def to_lowercase(input_list):
    return [item.lower() for item in input_list]

school_1 = to_lowercase(school_1)




def eliminate_duplicates(input_list):
    return list(set(input_list))

school_1 =eliminate_duplicates(school_1)
school_1
# Out:
# [' nestm',
#  '316',
#  '300',
#  'tbd',
#  'na',
#  'anderson',
#  'any city-wide',
#  'anderson nest tag q300',
#  ' ps130',
#  ' 166',
#  'lower lab',
#  ' ps 11',
#  'nest',
#  '198',
#  ' ps174',
#  ' 11',
#  'brooklyn school of inquiry',
#  '33',
#  'ps130',
#  ' nest+t',
#  ' ps188',
#  'q300',
#  'ps50',
#  'anderson (sibling)',
#  ' 38',
#  ' ps124',
#  ' 334',
#  'ps121 ',
#  ' 12 ',
#  ' 174',
#  '11',
#  'ps229',
#  ' ps 33',
#  ' 217',
#  'ps205',
#  '124',
#  'likely staying in zoned schools; d15 g&t options are limited.',
#  ' ps203',
#  '111',
#  ' ps163',
#  '144',
#  ' ll',
#  ' nest+m',
#  ' ps77',
#  ' q300',
#  'll',
#  'tag',
#  'p.s.203q',
#  ' tag',
#  'nest/ps33',
#  ' nest + m',
#  'nest+m',
#  'nest/anderson/q300',
#  ' 33',
#  ' 124',
#  ' ps166',
#  ' ps11',
#  'bsi',
#  ' anderson',
#  ' tag young',
#  'ps53',
#  ' bsi',
#  ' 122',
#  'any citywide or district 3 school',
#  'ps11',
#  ' nest',
#  'ps188',
#  ' ps144',
#  ' lower lab',
#  ' ',
# ...

# %%
d1 = dict((v,k) for k,v in zip(range(len(df2['School Preferences'], school_1.unique()))
# create column
df2['School Preferences_index'] = df2['School Preferences'].map(d1)
# Out:
#   File "/var/folders/yc/1grccybs4xn0vfqdc4833t6w0000gn/T/ipykernel_13066/2301819774.py", line 3
#     df2['School Preferences_index'] = df2['School Preferences'].map(d1)
#     ^
# SyntaxError: invalid syntax

# %%
d1
# Out:
# {'NEST+m, TAG, Anderson, Q300': 1,
#  'Anderson, NEST+m': 2,
#  'Anderson': 3,
#  'Brooklyn School of Inquiry': 4,
#  'Anderson NEST TAG Q300': 5,
#  'Nest+M, Anderson': 6,
#  'Any citywide or district 3 school': 7,
#  'PS121 ': 8,
#  'Anderson, NEST+M, Lower Lab': 9,
#  'PS Q203': 10,
#  'Likely staying in zoned schools; D15 G&T options are limited.': 11,
#  'TBD': 12}

# %%
df2['School Preferences_index']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 112   NaN
# 113   NaN
# 114   NaN
# 115   NaN
# 116   NaN
# Name: School Preferences_index, Length: 117, dtype: float64

# %%
df2['School Preferences_index'].fillna(value=4.0, inplace=True)

# %%
df2.drop('School Preferences', axis = 1, inplace = True)

# %%
df2
# Out:
#                Timestamp Entering Grade Level  District  Overall Score  \
# 0       4/8/2017 6:44:01                    1   6.00000             99
# 1      4/7/2017 10:40:45                    0  12.50495             99
# 2      4/7/2017 10:41:56                    1  12.50495             98
# 3      4/7/2017 10:43:31                    0  12.50495             98
# 4     4/10/2017 10:18:34                    0  22.00000             99
# ..                   ...                  ...       ...            ...
# 112   6/20/2017 16:06:54                    1   2.00000             99
# 113   6/21/2017 22:52:59                    0  20.00000             98
# 114   9/14/2017 16:39:55                    0  32.00000             99
# 115  11/19/2017 17:07:05                    0   4.00000             91
# 116   1/11/2019 15:03:41                    0   2.00000             98
#
#                               School Assigned Will you enroll there?  \
# ...

# %%
d = dict((v,k) for k,v in zip(range(1, 13), df2['School Assigned'].unique()))
# create column
df2['School Assigned_index'] = df2['School Assigned'].map(d)

# %%
df2.drop('School Assigned', axis = 1, inplace = True)

# %%
df2
# Out:
#                Timestamp Entering Grade Level  District  Overall Score  \
# 0       4/8/2017 6:44:01                    1   6.00000             99
# 1      4/7/2017 10:40:45                    0  12.50495             99
# 2      4/7/2017 10:41:56                    1  12.50495             98
# 3      4/7/2017 10:43:31                    0  12.50495             98
# 4     4/10/2017 10:18:34                    0  22.00000             99
# ..                   ...                  ...       ...            ...
# 112   6/20/2017 16:06:54                    1   2.00000             99
# 113   6/21/2017 22:52:59                    0  20.00000             98
# 114   9/14/2017 16:39:55                    0  32.00000             99
# 115  11/19/2017 17:07:05                    0   4.00000             91
# 116   1/11/2019 15:03:41                    0   2.00000             98
#
#     Will you enroll there?  month_index  OLSAT Verbal Percentile  \
# ...

# %%
df2['School Preferences_index'].fillna(value=5.0, inplace=True)

# %%
df2
df2['School Assigned_index'].fillna(value=4.0, inplace=True)

# %%
df2.corr()
# Out:
#                             District  Overall Score  month_index  \
# District                    1.000000      -0.239713     0.004640
# Overall Score              -0.239713       1.000000     0.062819
# month_index                 0.004640       0.062819     1.000000
# OLSAT Verbal Percentile    -0.214108       0.874456     0.008358
# OLSAT Verbal Score         -0.214108       0.874456     0.008358
# NNAT Non Verbal Percentile -0.173096       0.747719     0.137730
# NNAT Non Verbal Raw Score  -0.173096       0.747719     0.137730
# School Preferences_index         NaN            NaN          NaN
# School Assigned_index      -0.191239       0.035931    -0.002960
#
#                             OLSAT Verbal Percentile  OLSAT Verbal Score  \
# District                                  -0.214108           -0.214108
# Overall Score                              0.874456            0.874456
# month_index                                0.008358            0.008358
# ...

# %%
import matplotlib.pyplot as plt

plt.matshow(df2.corr())
plt.show()

# %%
import seaborn as sns
corr = df2.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_theme(style="dark")
sns.displot(df2['OLSAT Verbal Score'])

title = plt.title("OLSAT Verbal Score")

# %%
df2.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'District'}>,
#         <AxesSubplot:title={'center':'Overall Score'}>,
#         <AxesSubplot:title={'center':'month_index'}>],
#        [<AxesSubplot:title={'center':'OLSAT Verbal Percentile'}>,
#         <AxesSubplot:title={'center':'OLSAT Verbal Score'}>,
#         <AxesSubplot:title={'center':'NNAT Non Verbal Percentile'}>],
#        [<AxesSubplot:title={'center':'NNAT Non Verbal Raw Score'}>,
#         <AxesSubplot:title={'center':'School Preferences_index'}>,
#         <AxesSubplot:title={'center':'School Assigned_index'}>]],
#       dtype=object)

# %%
df2.describe()
# Out:
#          District  Overall Score  month_index  OLSAT Verbal Percentile  \
# count  117.000000     117.000000   117.000000               117.000000
# mean    12.504950      97.564103     6.846154                94.717949
# std     10.590842       2.798967     3.341524                 7.384567
# min      1.000000      76.000000     1.000000                55.000000
# 25%      2.000000      97.000000     4.000000                95.000000
# 50%     12.504950      99.000000     6.000000                98.000000
# 75%     22.000000      99.000000    10.000000                99.000000
# max     32.000000      99.000000    12.000000                99.000000
#
#        OLSAT Verbal Score  NNAT Non Verbal Percentile  \
# count          117.000000                  117.000000
# mean            28.415385                   98.632479
# std              2.215370                    1.393323
# min             16.500000                   90.000000
# ...
