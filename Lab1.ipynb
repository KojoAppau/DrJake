# %%
import random
n = 0
student_id = [random.randint(1, 9999999) for _ in range(200)]
student_last2=[]

for x in range(len(student_id)):
    student_last2.append(str(student_id[x])[-2:])
    
    

student_last2
# Out:
# ['12',
#  '35',
#  '50',
#  '53',
#  '74',
#  '31',
#  '47',
#  '52',
#  '74',
#  '69',
#  '37',
#  '96',
#  '01',
#  '77',
#  '96',
#  '92',
#  '69',
#  '73',
#  '78',
#  '00',
#  '35',
#  '61',
#  '44',
#  '43',
#  '81',
#  '02',
#  '18',
#  '12',
#  '17',
#  '99',
#  '79',
#  '55',
#  '51',
#  '63',
#  '09',
#  '47',
#  '20',
#  '49',
#  '54',
#  '11',
#  '21',
#  '80',
#  '32',
#  '04',
#  '35',
#  '23',
#  '65',
#  '27',
#  '91',
#  '51',
#  '98',
#  '61',
#  '59',
#  '92',
#  '01',
#  '18',
#  '94',
#  '06',
#  '81',
#  '32',
#  '37',
#  '05',
#  '27',
#  '44',
#  '22',
#  '97',
#  '67',
#  '49',
#  '79',
#  '73',
#  '85',
#  '60',
#  '48',
#  '60',
#  '32',
#  '59',
#  '21',
#  '14',
#  '22',
#  '08',
#  '25',
#  '26',
#  '04',
#  '14',
#  '23',
#  '00',
#  '46',
#  '98',
#  '56',
#  '31',
#  '86',
#  '00',
#  '04',
#  '84',
#  '31',
#  '04',
#  '85',
#  '24',
#  '24',
#  '11',
#  '19',
#  '50',
#  '66',
#  '69',
#  '44',
#  '71',
#  '79',
#  '66',
#  '90',
#  '11',
#  '23',
# ...
